# %% [markdown]
# # Project 4: working with CSV data
#
# In this project, you'll take some real-world data stored as a CSV file, load it into Python, analyze it, and create some plots.  Along the way, we hope you'll ask questions about where the data comes from, what the plots show, and what this might (or might not) mean for public policy.

# %% [markdown]
# To begin, take a look a this article from the US Bureau of Labor Statistics: [Share of workplace deaths among Hispanic and Latino workers continued to rise in 2020](https://www.bls.gov/opub/ted/2022/share-of-workplace-deaths-among-hispanic-and-latino-workers-continued-to-rise-in-2020.htm)
#
# Your first task is to reproduce this plot using the real data:
#
# ![hispanic-and-latino-work-small.png](attachment:hispanic-and-latino-work-small.png)
#
# Your second task is to make a better plot. :-)
#
#
# ## Useful references
# * [Census of Fatal Occupational Injuries News Release (2020)](https://www.bls.gov/news.release/archives/cfoi_12162021.htm
# ) -- This document describes a little bit about what data was collected and how, and shows data tables with a number of different breakdowns for the last five years.
# * [Census of Fatal Occupational Injuries (CFOI) data page](https://www.bls.gov/iif/oshcfoi1.htm) -- Contains links to year-by-year breakdowns of CFOI data (go to the [archive](https://www.bls.gov/iif/oshcfoiarchive.htm#OTHER) for older data).
#
#
# ## Part 1: reproducing the plot
# 1. Write code to read the data from the CSV file into a Python data structure.  For plotting, it will probably be most convenient to have parallel arrays (e.g., one array with the years, and a corresponding array for each race group).
# 2. Calculate the percentage shown in the plot.  You can do this however you'd like, but NumPy will make this particularly easy.
# 3. Make a matching plot.
#
# *Challenge*: Make your plot look exactly like the plot from the BLS article.  (It's is not a particularly great plot, but trying to mimic the style will expand your matplotlib skills.)

# %%
# Your code here...

# %% [markdown]
# ## Part 2: designing a better plot
#
# Using the same data, produce a more engaging and/or more informative plot.  Think about how you might show more data and draw viewers into engaging and analyzing the data themselves.

# %%
# Your code here...

# %% [markdown]
# ## Analysis
# Replace this cell with an explanation of how you designed your plot.
#
# * What is your aim and/or inspiration for your design?
# * Why did you choose the encoding (length, position, angle, color, etc) that you did?
# * How did you settle on these particular color(s)?
# * What do your axis markings add to the plot?
